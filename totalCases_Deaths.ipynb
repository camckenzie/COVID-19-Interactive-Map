# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import requests, io
import zipfile as zf
import shutil
import os

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
file_path = os.getcwd()
print(file_path)

plt.style.use('ggplot')
# Out:
# C:\Users\Andrew

# %%
df = pd.read_csv(r"C:\College\Spring 2021\CS545\totalCases_Deaths.csv", skiprows=3)

# %%
df
# Out:
#              State/Territory  Total Cases  Confirmed Cases  Probable Cases  \
# 0                     Alaska        57449                0               0
# 1                    Alabama       501398           393278          108120
# 2                   Arkansas       325700                0               0
# 3             American Samoa            4                0               0
# 4                    Arizona       828630           771541           57089
# ..                       ...          ...              ...             ...
# 57             West Virginia       134158           107100           27058
# 58                   Wyoming        55014            46588            8426
# 59  United States of America     29052862         13299391         1938389
# 60                  New York       950806                0               0
# 61             New York City       767535           644461          123074
#
#     Cases in Last 7 Days  Case Rate per 100000  Total Deaths  \
# 0                    844                  7853           301
# 1                   4244                 10226         10222
# 2                   2347                 10793          5382
# 3                      0                     7             0
# 4                   8676                 11384         16404
# ..                   ...                   ...           ...
# 57                  1742                  7486          2330
# 58                   398                  9506           691
# 59                470141                  8751        527726
# 60                 23056                  8601         18303
# 61                 26410                  9139         30059
#
#     Confirmed Deaths  Probable Deaths  Deaths in Last 7 Days  \
# 0                NaN              NaN                      2
# 1             8035.0           2187.0                    193
# 2                NaN              NaN                    121
# 3                NaN              NaN                      0
# 4            14477.0           1927.0                    315
# ..               ...              ...                    ...
# 57               NaN              NaN                     21
# 58             691.0              0.0                      9
# 59          263397.0          31421.0                  10391
# 60               NaN              NaN                    211
# 61           25024.0           5035.0                    422
#
#     Death Rate per 100000  7-Day Cases Rate per 100000  \
# 0                      41                        115.4
# 1                     208                         86.6
# 2                     178                         77.8
# 3                       0                          0.0
# 4                     225                        119.2
# ..                    ...                          ...
# 57                    130                         97.2
# 58                    119                         68.8
# 59                    158                        141.6
# 60                    165                        208.6
# 61                    357                        314.5
#
#     7-Day Death Rate per 100000
# 0                           0.3
# 1                           3.9
# 2                           4.0
# 3                           0.0
# 4                           4.3
# ..                          ...
# 57                          1.2
# 58                          1.6
# 59                          3.1
# 60                          1.9
# 61                          5.0
#
# [62 rows x 13 columns]

# %%
df.iloc[[58],[0,1,2,4,5,6]]
# Out:
#    State/Territory  Total Cases  Confirmed Cases  Cases in Last 7 Days  \
# 58         Wyoming        55014            46588                   398
#
#     Case Rate per 100000  Total Deaths
# 58                  9506           691
